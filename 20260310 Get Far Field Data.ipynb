# %%
# %load_ext autoreload
# %autoreload 2
import os
from dotenv import load_dotenv
load_dotenv()
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from natsort import natsorted
import numpy as np
import sys

# This notebook reduces heavy incoming Tidy3D results to the projected far-field data only.
# Assuming /AutomationModule is in the root directory of your project
sys.path.append(os.path.abspath(rf'./'))

from AutomationModule import * 

import AutomationModule as AM
plt.rcParams.update({'font.size': 22})  

tidy3dAPI = os.environ["API_TIDY3D_KEY"]

# %%
# Load the lightweight HDF5 archive that stores only previously extracted projected fields.
data_path = "./data/20251006_far_field_eps_8p57_ff_21p72_air.h5" #Path to the hdf5 file where the far field data will be stored
data_old = AM.read_hdf5_as_dict(data_path)
data_old.keys()
# Out:
# dict_keys(['n_2.9275_ff_0.2172_size_0.34965034965034963', 'n_2.9275_ff_0.2172_size_0.6118881118881119', 'n_2.9275_ff_0.2172_size_0.6993006993006993', 'n_2.9275_ff_0.2172_size_0.7867132867132867', 'n_2.9275_ff_0.2172_size_0.8741258741258741'])

# %% [markdown]
# ## Lightweight far-field export
#
# Incoming Tidy3D result files are too heavy to keep around as full simulation objects for routine post-processing.
#
# This notebook is meant to extract only the projected far-field quantities needed downstream and save them in a compact HDF5 file.
#
# The goal is to preserve the projected fields and their coordinate grid, not the full Tidy3D payload.

# %%
data = data_old
for path_direction in [
                  rf"./data/20251006 Far Field Transmission LSU ff_21p72_5x_size_perm_8.57/z_incidence" # Folder created with the ids of the simulations with z_incidence direction
                       ]:
      folder_path = f"{path_direction}"
      
     
      for i,filename in enumerate(natsorted(os.listdir(folder_path))):
            sim_name = Path(filename).stem
            if not Path(filename).suffix==".txt":
                  continue
            print(sim_name)
            if sim_name in data.keys():
                  print(f"{sim_name} already in data, skipping...")
                  continue
            if os.path.isfile(os.path.join(folder_path, filename)):
                  file=os.path.join(folder_path, filename)
                  # Raw Tidy3D files are too heavy to keep in memory or archive here.
                  structure_1 = AM.loadFromFile(key = tidy3dAPI, file_path=file)
                 
                  if sim_name not in data.keys():
                        data[sim_name] = {}

                  # Keep only the projected far-field components needed for later analysis.
                  data[sim_name]["Etheta"] = structure_1.sim_data["far_field"].Etheta.squeeze().values
                  data[sim_name]["Ephi"] = structure_1.sim_data["far_field"].Ephi.squeeze().values
# Out:
# n_2.9275_ff_0.2172_size_0.6118881118881119
# n_2.9275_ff_0.2172_size_0.6118881118881119 already in data, skipping...
# n_2.9275_ff_0.2172_size_0.6993006993006993
# n_2.9275_ff_0.2172_size_0.6993006993006993 already in data, skipping...
# n_2.9275_ff_0.2172_size_0.7867132867132867
# n_2.9275_ff_0.2172_size_0.7867132867132867 already in data, skipping...
# n_2.9275_ff_0.2172_size_0.8741258741258741
# n_2.9275_ff_0.2172_size_0.8741258741258741 already in data, skipping...
# n_2.9275_ff_0.2172_size_0.34965034965034963
# n_2.9275_ff_0.2172_size_0.34965034965034963 already in data, skipping...
# n_2.9275_ff_0.2172_size_1.0489510489510487
# Configured successfully.
# 11:27:55 W. Europe Standard Time WARNING: No connection: Retrying for 180
#                                  seconds.
# No Reference Simulation was found
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
# Save only the extracted projected fields so the heavy raw Tidy3D files are no longer needed here.
create_hdf5_from_dict(data,"./data/20251006_far_field_eps_8p57_ff_21p72_air.h5")

# %%
# Reference simulation (empty cell)

# The incoming Tidy3D objects are too heavy, so only the projected field grid is exported.
r_proj=(structure_1.sim_data["far_field"].r)
theta_proj=structure_1.sim_data["far_field"].theta
phi_proj=structure_1.sim_data["far_field"].phi
lambdas = (td.C_0/structure_1.sim_data["far_field"].f)

data_parameters = {
    "r_proj":r_proj,
    "theta_proj":theta_proj,
    "phi_proj":phi_proj,
    "lambdas":lambdas
}

# Store only the projected coordinates required downstream, not the full simulation payload.
create_hdf5_from_dict(data_parameters,"20250708_far_field_eps_10p89_ff_20p45_decaline_and_air_params.h5")
